# %% [markdown]
# <a href="https://colab.research.google.com/github/hsliz31/python_algorithm/blob/main/08_%EB%A6%AC%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 08 리스트 (List)
# - 데이터에 순서를 매겨 늘어놓는 자료구조
# - 스택과 큐 도 리스트 자료 구조에 속함

# %% [markdown]
# ### 08-1 연결 리스트 (단순 / 기본구조)
# 공부일자 : 2025-11-25

# %% [markdown]
# 1. 선형 리스트 (linear list)
# 2. 연결 리스트 (linked list)
#
# A > B > C > D
# * 이런 구조에서는 누군가를 건너뛰거나 뒤돌아 앞 사람에게 연락해서는 안됨
#
# * 연결 리스트에서 각각의 원소(element)를 `node` 라고 함
#
# * `node` 는
#     - `데이터`와
#     - 뒤쪽 노드를 가리키는(참조하는) `pointer` 를 갖고 있음
#
# #### **배열로 연결 리스트 만들기**
# 데이터를 삽입-삭제함에 따라 데이터를 옮겨야 하므로 효율적이지 않음

# %% [markdown]
# ### 08-2 포인터를 이용한 연결 리스트
# 공부일자: 2025-11-25

# %% [markdown]
# #### **class Node**
# - __init__() 함수가 있음
#
# #### **field**
# class Node 는 2개의 필드로 구성
# 1. data - 데이터에 대한 참조 : 임의의 형
# 2. next - 뒷쪽 노드에 대한 참조 : Node 형

# %%
# 포인터로 연결 리스트 구현하기

from __future__ import annotations
from typing import Any, Type

class Node :
  """ 연결 리스트용 노드 클래스"""

  def __init__(self, data : Any = None, next : Node = None):
    """초기화"""
    self.data = data #데이터
    self.next = next #뒤쪽 포인터

# %% [markdown]
# 보충수업 : 파이썬의 리스트는 자료 구조가 아닙니다
#
# - 연결 리스트의 장점 : 임의의 위치에 원소를 삽입하거나 삭제할 때 빠르게 수행 할 수 있음
# - 단점 : 메모리 (기억 영역) 과 속도 면에서는 배열 보다 효율이 떨어짐
#
# 파이썬의 리스트
# - 연결 리스트의 자료 구조가 아니라 모든 원소를 연속으로 메모리에 배치하는 '배열'로 내부에서 구현함

# %% [markdown]
# ### 08-3 커서를 이용한 연결 리스트

# %% [markdown]
# ### 08-4 원형 이중 연결 리스트
