# %% [markdown]
# <a href="https://colab.research.google.com/github/hsliz31/python_algorithm/blob/main/06_%EC%A0%95%EB%A0%AC_%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 06 정렬 알고리즘

# %% [markdown]
# ### 06-1 정렬 알고리즘

# %% [markdown]
# ### 06-2 버블 정렬

# %% [markdown]
# ### 06-3 단순 선택 정렬

# %% [markdown]
# ### 06-4 단순 삽입 정렬

# %% [markdown]
# ### 06-5 셸 정렬

# %% [markdown]
# ### 06-6 퀵 정렬

# %% [markdown]
# ### 06-7 병합 정렬

# %% [markdown]
# ### 06-8 힙 정렬
#
# 2025-12-04 : 완전 이진 트리 completely binary tree 를 알아보는 과정에서
# - 높이가 k 일 때 이진 트리가 가질 수 있는 노드의 최대 개수 : $2^{k+1} - 1$
# - n 개의 노드를 저장할 수 있는 완전 이진 트리의 높이는 $\log n$

# %% [markdown]
# ### 06-9 도수 정렬
